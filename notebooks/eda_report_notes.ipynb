# %% [markdown]
# # Comentarios DS sobre o `eda_report.html`
#
# Notebook gerado automaticamente para registrar os principais achados do relatorio HTML consolidado das categorias `UberX`, `Uber Comfort` e `Uber Black`.
#
# ## Configuracao do Relatorio
#
# - Fonte: `C:\Users\rodrigo.neiland\OneDrive - ESPM\Documentos\3sem\Martech\ml-price-prediction\data\analytical`
# - Populacao filtrada: `1109259` linhas
# - Amostra Sweetviz: `300000` linhas (100000 por categoria, quando disponivel)
# - Parametros: `pairwise_analysis='off'`, `CategoryName` tratada como feature categorial-chave e features temporais derivadas de `Create`.
#
# ## Principais Achados
#
# - `UberX` domina o volume (`710134` linhas) e exibe a maior cauda de `Price` (`p99=125.0`, `max=13918.82`).
# - `Uber Black` tem o preco tipico mais alto (mediana `44.0`), o que reforca a necessidade de modelagem segmentada ou com interacoes por categoria.
# - `Uber Comfort` continua assimetrico (`skew=55.5139`) e nao pode ser tratado como distribuicao aproximadamente normal.
# - O missing de `FareID` segue estrutural (`UberX=50.03%`, `Uber Comfort=2.88%`, `Uber Black=1.04%`), entao a estrategia de sentinel continua correta.
# - `WaitingTime` tem p95 curto (`UberX=10.0`, `Uber Comfort=10.0`, `Uber Black=14.0`), o que sugere relacao nao linear com `Price` e utilidade para binning.
# - Os gaps entre `Schedule` e `Create` seguem pequenos no recorte: `>60s=720` e `>300s=0`.
#
# ## Encaminhamento
#
# - Usar o HTML como visao navegavel consolidada e manter as regras de tratamento ja documentadas na camada curada antes do treino.
# - Priorizar features por categoria, interacoes temporais e transformacoes robustas para o target devido a assimetria residual.
